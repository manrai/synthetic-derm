# %%
import pandas as pd
import torch
from fastai.vision.all import *
from sklearn.model_selection import train_test_split
import wandb
from fastai.callback.wandb import *
from statsmodels.stats.proportion import proportion_confint
from itertools import product
import os

# %%
# Datasets
synthetic_derm = "lukemelas/synthetic-derm"  # 440 total images in each class using all_generations
fitz17 = "n/data1/hms/dbmi/manrai/derm/Fitzpatrick17k/" # Replace this with your own data directory


#image_dir = "/n/data1/hms/dbmi/manrai/derm/"

# %%
# Load in the labels we are using for training data
# TODO: these should be stored in the huggingface repo
metadata_train = pd.read_csv("/n/data1/hms/dbmi/manrai/derm/Fitzpatrick17k/fitzpatrick17k_10label_clean_training.csv")
top_n_labels = metadata_train["label"].value_counts().index[:9]
metadata_train = metadata_train[metadata_train["label"].isin(top_n_labels)].reset_index(drop=True)
metadata_train["synthetic"] = False

# These are the labels we are using for testing
metadata_test = pd.read_csv("/n/data1/hms/dbmi/manrai/derm/Fitzpatrick17k/fitzpatrick17k_10label_clean_held_out_set.csv")
metadata_test = metadata_test[metadata_test["label"].isin(top_n_labels)].reset_index(drop=True)
metadata_test["synthetic"] = False

ids_train = set(metadata_train["md5hash"])
ids_test = set(metadata_test["md5hash"])

if ids_train.isdisjoint(ids_test):
    print("train/test mutually exclusive.")
else:
    print("train/test not mutually exclusive.")
# Out:
# train/test mutually exclusive.

# %% [markdown]
# ## Train a model with 32 real training images per disease condition

# %% [markdown]
# We will train a model with 32 real images per class, with and without synthetic images

# %%
# Set image directory and fastai path
image_dir = "/n/data1/hms/dbmi/manrai/derm/"
path = Path(image_dir)

# Set the random seed
random_state = 111108

# Set the generation folder
generation_folder = "all_generations/finetune-inpaint/"
generation_type = "inpaint"

# %%
n_synthetic_per_real = 10

# First, the dataset is duplicated n_synthetic_per_real times
df = pd.concat([metadata_train]*n_synthetic_per_real, ignore_index=True)

# create a variable that represents the nth copy of the image
df['n'] = df.groupby('md5hash').cumcount()
df['location'] = generation_folder + df['label'].str.replace(' ', '-')  + '/' + generation_type +'/0' + df['n'].astype(str) + '/' + df['md5hash'] + '.png'
df['synthetic'] = True
df['Qc'] = ''

# drop the 'n' column
df = df.drop(columns=['n'])

# %%
df.head()
# Out:
#                             md5hash  fitzpatrick_scale  fitzpatrick_centaur  \
# 0  fa2911a9b13b6f8af79cb700937cc14f                  1                    1
# 1  0a94359e7eaacd7178e06b2823777789                  1                    1
# 2  a39ec3b1f22c08a421fa20535e037bba                  1                    1
# 3  6c395be9325dbb10e55497304b398253                  2                    2
# 4  09d46db9589ff45436cda87c4abc946b                  3                    2
#
#                          label nine_partition_label three_partition_label  \
# 0              photodermatoses         inflammatory        non-neoplastic
# 1                    psoriasis         inflammatory        non-neoplastic
# 2                    psoriasis         inflammatory        non-neoplastic
# 3      neutrophilic dermatoses         inflammatory        non-neoplastic
# 4  allergic contact dermatitis         inflammatory        non-neoplastic
#
#     qc  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#                                                                                                                    url  \
# 0                         https://www.dermaamin.com/site/images/clinical-pic/p/photosensitivity/photosensitivity18.jpg
# 1                                       https://www.dermaamin.com/site/images/clinical-pic/p/psoriasis/psoriasis38.jpg
# 2                           https://www.dermaamin.com/site/images/clinical-pic/p/psoriasis-scalp/psoriasis-scalp20.jpg
# 3                             https://www.dermaamin.com/site/images/clinical-pic/s/sweet-syndrome/sweet-syndrome98.jpg
# 4  https://www.dermaamin.com/site/images/clinical-pic/a/allergic_contact_dermatitis/allergic_contact_dermatitis114.jpg
#
#                                                                                             url_alphanum  \
# 0                     httpwwwdermaamincomsiteimagesclinicalpicpphotosensitivityphotosensitivity18jpg.jpg
# 1                                   httpwwwdermaamincomsiteimagesclinicalpicppsoriasispsoriasis38jpg.jpg
# 2                         httpwwwdermaamincomsiteimagesclinicalpicppsoriasisscalppsoriasisscalp20jpg.jpg
# 3                           httpwwwdermaamincomsiteimagesclinicalpicssweetsyndromesweetsyndrome98jpg.jpg
# 4  httpwwwdermaamincomsiteimagesclinicalpicaallergiccontactdermatitisallergiccontactdermatitis114jpg.jpg
#
#    synthetic  \
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#
#                                                                                                        location  \
# 0              all_generations/finetune-inpaint/photodermatoses/inpaint/00/fa2911a9b13b6f8af79cb700937cc14f.png
# 1                    all_generations/finetune-inpaint/psoriasis/inpaint/00/0a94359e7eaacd7178e06b2823777789.png
# 2                    all_generations/finetune-inpaint/psoriasis/inpaint/00/a39ec3b1f22c08a421fa20535e037bba.png
# 3      all_generations/finetune-inpaint/neutrophilic-dermatoses/inpaint/00/6c395be9325dbb10e55497304b398253.png
# 4  all_generations/finetune-inpaint/allergic-contact-dermatitis/inpaint/00/09d46db9589ff45436cda87c4abc946b.png
#
#   Qc
# 0
# 1
# 2
# 3
# 4

# %%
train, val = synthetic_train_val_split(
    real_data=metadata_train, 
    synthetic_data = df, 
    per_class_size=40,
    n_real_per_class = 32,
    random_state = random_state,
    class_column = "label",
    id_column = "md5hash"
    )

# %%
train
# Out:
#                                 md5hash  fitzpatrick_scale  \
# 0      161e5aa485b14a77a2dee45d20052a19                  2
# 1      667743ac9cf8862ac3ffcc143a6825af                  2
# 2      47df3741647f00f3713af546424df866                  2
# 3      dc4852bdb88ee7e126d9d2078cdb1612                  1
# 4      fd2e0985058e54e4ced9910e56f9f6b5                  2
# ...                                 ...                ...
# 33673  de727a04c900af1fd7f413c121a18199                  4
# 33674  cb5b385f3f6d18339194aeb3955f30ac                  6
# 33675  218ea232ca4b0255a395886ee86cbada                  3
# 33676  642718dcaa658d3fb796ca2f07f6e6d2                  3
# 33677  77ff4dccc56baa53ba9ec3b95b5aa8fb                  5
#
#        fitzpatrick_centaur                        label nine_partition_label  \
# 0                        1  allergic contact dermatitis         inflammatory
# 1                        1  allergic contact dermatitis         inflammatory
# 2                        1  allergic contact dermatitis         inflammatory
# 3                        1  allergic contact dermatitis         inflammatory
# 4                        2  allergic contact dermatitis         inflammatory
# ...                    ...                          ...                  ...
# 33673                    3                lichen planus         inflammatory
# 33674                    6          lupus erythematosus         inflammatory
# 33675                    2         basal cell carcinoma  malignant epidermal
# 33676                    3      neutrophilic dermatoses         inflammatory
# 33677                   -1                lichen planus         inflammatory
#
#       three_partition_label             qc  \
# 0            non-neoplastic            NaN
# 1            non-neoplastic            NaN
# 2            non-neoplastic            NaN
# 3            non-neoplastic  5 Potentially
# 4            non-neoplastic            NaN
# ...                     ...            ...
# 33673        non-neoplastic            NaN
# 33674        non-neoplastic            NaN
# 33675             malignant            NaN
# 33676        non-neoplastic            NaN
# 33677        non-neoplastic  5 Potentially
#
#                                                                                                                       url  \
# 0                              https://www.dermaamin.com/site/images/clinical-pic/r/rhus_dermatitis/rhus_dermatitis21.jpg
# 1      https://www.dermaamin.com/site/images/clinical-pic/a/allergic_contact_dermatitis/allergic_contact_dermatitis46.jpg
# 2                        https://www.dermaamin.com/site/images/clinical-pic/c/contact_dermatitis/contact_dermatitis14.jpg
# 3      https://www.dermaamin.com/site/images/clinical-pic/I/irritant-contact-dermatitis/irritant-contact-dermatitis21.jpg
# 4      https://www.dermaamin.com/site/images/clinical-pic/a/allergic_contact_dermatitis/allergic_contact_dermatitis55.jpg
# ...                                                                                                                   ...
# 33673                                                                   http://atlasdermatologico.com.br/img?imageId=3744
# 33674                                                                   http://atlasdermatologico.com.br/img?imageId=4099
# 33675                                                                    http://atlasdermatologico.com.br/img?imageId=586
# 33676                                                                   http://atlasdermatologico.com.br/img?imageId=6921
# 33677                                                                   http://atlasdermatologico.com.br/img?imageId=3842
#
#                                                                                                url_alphanum  \
# 0                            httpwwwdermaamincomsiteimagesclinicalpicrrhusdermatitisrhusdermatitis21jpg.jpg
# 1      httpwwwdermaamincomsiteimagesclinicalpicaallergiccontactdermatitisallergiccontactdermatitis46jpg.jpg
# 2                      httpwwwdermaamincomsiteimagesclinicalpicccontactdermatitiscontactdermatitis14jpg.jpg
# 3      httpwwwdermaamincomsiteimagesclinicalpicIirritantcontactdermatitisirritantcontactdermatitis21jpg.jpg
# 4      httpwwwdermaamincomsiteimagesclinicalpicaallergiccontactdermatitisallergiccontactdermatitis55jpg.jpg
# ...                                                                                                     ...
# 33673                                                      httpwwwatlasdermatologicocombrimgimageId3744.jpg
# 33674                                                      httpwwwatlasdermatologicocombrimgimageId4099.jpg
# 33675                                                       httpwwwatlasdermatologicocombrimgimageId586.jpg
# 33676                                                      httpwwwatlasdermatologicocombrimgimageId6921.jpg
# 33677                                                      httpwwwatlasdermatologicocombrimgimageId3842.jpg
#
#        synthetic  \
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 33673       True
# 33674       True
# 33675       True
# 33676       True
# 33677       True
#
#                                                                                                        location  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
# ...                                                                                                         ...
# 33673            all_generations/finetune-inpaint/lichen-planus/inpaint/09/de727a04c900af1fd7f413c121a18199.png
# 33674      all_generations/finetune-inpaint/lupus-erythematosus/inpaint/09/cb5b385f3f6d18339194aeb3955f30ac.png
# 33675     all_generations/finetune-inpaint/basal-cell-carcinoma/inpaint/09/218ea232ca4b0255a395886ee86cbada.png
# 33676  all_generations/finetune-inpaint/neutrophilic-dermatoses/inpaint/09/642718dcaa658d3fb796ca2f07f6e6d2.png
# 33677            all_generations/finetune-inpaint/lichen-planus/inpaint/09/77ff4dccc56baa53ba9ec3b95b5aa8fb.png
#
#         Qc  is_valid
# 0      NaN     False
# 1      NaN     False
# 2      NaN     False
# 3      NaN     False
# 4      NaN     False
# ...    ...       ...
# 33673          False
# 33674          False
# 33675          False
# 33676          False
# 33677          False
#
# [33678 rows x 13 columns]

# %%
val
# Out:
#                               md5hash  fitzpatrick_scale  fitzpatrick_centaur  \
# 0    e4eaa82b962f827f69009449d0a8cbc2                 -1                    1
# 1    2f3ec777d8f2af1a89f86ef3cef7a409                  2                    1
# 2    76027292304f381e5567eae73242932c                  2                    1
# 3    b920dcbc6e05b75aaf5b4159b4682f36                  2                    1
# 4    523cdfb89a2bc15e2663b0f584b59a51                  3                    3
# ..                                ...                ...                  ...
# 355  09a75e2a4e9bbc303e6e0cb3e16a32d8                  3                    3
# 356  b89758afa9975102aa1f58322cf3c8fa                  6                    5
# 357  fd356daecf2740e664f15b74711d0c4c                  2                    1
# 358  9748eb88f98e00ea924badf9e3aa89b2                 -1                   -1
# 359  a1026872297e8c4f18b11cba25cc10c1                  2                    2
#
#                            label nine_partition_label three_partition_label  \
# 0    allergic contact dermatitis         inflammatory        non-neoplastic
# 1    allergic contact dermatitis         inflammatory        non-neoplastic
# 2    allergic contact dermatitis         inflammatory        non-neoplastic
# 3    allergic contact dermatitis         inflammatory        non-neoplastic
# 4    allergic contact dermatitis         inflammatory        non-neoplastic
# ..                           ...                  ...                   ...
# 355      squamous cell carcinoma  malignant epidermal             malignant
# 356      squamous cell carcinoma  malignant epidermal             malignant
# 357      squamous cell carcinoma  malignant epidermal             malignant
# 358      squamous cell carcinoma  malignant epidermal             malignant
# 359      squamous cell carcinoma  malignant epidermal             malignant
#
#       qc  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 355  NaN
# 356  NaN
# 357  NaN
# 358  NaN
# 359  NaN
#
#                                                                                                                     url  \
# 0          https://www.dermaamin.com/site/images/clinical-pic/a/acute_contact_dermatitis/acute_contact_dermatitis21.jpg
# 1                      https://www.dermaamin.com/site/images/clinical-pic/c/contact_dermatitis/contact_dermatitis79.jpg
# 2                      https://www.dermaamin.com/site/images/clinical-pic/c/contact_dermatitis/contact_dermatitis90.jpg
# 3    https://www.dermaamin.com/site/images/clinical-pic/a/allergic_contact_dermatitis/allergic_contact_dermatitis58.jpg
# 4                      https://www.dermaamin.com/site/images/clinical-pic/c/contact_dermatitis/contact_dermatitis54.jpg
# ..                                                                                                                  ...
# 355                                                                   http://atlasdermatologico.com.br/img?imageId=8874
# 356                          https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma84.jpg
# 357        https://www.dermaamin.com/site/images/clinical-pic/e/erythroplasia_of_queyrat/erythroplasia_of_queyrat13.jpg
# 358          https://www.dermaamin.com/site/images/clinical-pic/s/squamous-cell-carcinoma/squamous-cell-carcinoma18.jpg
# 359        https://www.dermaamin.com/site/images/clinical-pic/e/erythroplasia_of_queyrat/erythroplasia_of_queyrat19.jpg
#
#                                                                                              url_alphanum  \
# 0          httpwwwdermaamincomsiteimagesclinicalpicaacutecontactdermatitisacutecontactdermatitis21jpg.jpg
# 1                    httpwwwdermaamincomsiteimagesclinicalpicccontactdermatitiscontactdermatitis79jpg.jpg
# 2                    httpwwwdermaamincomsiteimagesclinicalpicccontactdermatitiscontactdermatitis90jpg.jpg
# 3    httpwwwdermaamincomsiteimagesclinicalpicaallergiccontactdermatitisallergiccontactdermatitis58jpg.jpg
# 4                    httpwwwdermaamincomsiteimagesclinicalpicccontactdermatitiscontactdermatitis54jpg.jpg
# ..                                                                                                    ...
# 355                                                      httpwwwatlasdermatologicocombrimgimageId8874.jpg
# 356                      httpwwwdermaamincomsiteimagesclinicalpickkeratoacanthomakeratoacanthoma84jpg.jpg
# 357        httpwwwdermaamincomsiteimagesclinicalpiceerythroplasiaofqueyraterythroplasiaofqueyrat13jpg.jpg
# 358          httpwwwdermaamincomsiteimagesclinicalpicssquamouscellcarcinomasquamouscellcarcinoma18jpg.jpg
# 359        httpwwwdermaamincomsiteimagesclinicalpiceerythroplasiaofqueyraterythroplasiaofqueyrat19jpg.jpg
#
#      synthetic  is_valid
# 0        False      True
# 1        False      True
# 2        False      True
# 3        False      True
# 4        False      True
# ..         ...       ...
# 355      False      True
# 356      False      True
# 357      False      True
# 358      False      True
# 359      False      True
#
# [360 rows x 11 columns]

# %% [markdown]
# ## Train a model with 32 real training images per disease condition

# %%
# We need to produce a train/test split

# %%
# Filter to the top 10 most common labels
top_n_labels = metadata['label'].value_counts().index[:9]
metadata = metadata[metadata['label'].isin(top_n_labels)].reset_index(drop=True)
metadata['location'] = 'Fitzpatrick17k/finalfitz17k/' + metadata['md5hash'] + '.jpg'
metadata['synthetic'] = False

# Take out 40 images from each label for testing
# test_data = pd.DataFrame(metadata.groupby(['label']).apply(lambda x: x.sample(n=40, random_state=random_state)).reset_index(drop=True))
test_data = pd.read_csv("../Metadata/fitzpatrick17k_10label_clean_held_out_set.csv")
test_data = test_data[test_data['label'].isin(top_n_labels)].reset_index(drop=True)
test_data['location'] = 'Fitzpatrick17k/finalfitz17k/' + test_data['md5hash'] + '.jpg'
test_data['synthetic'] = False
test_data['is_valid'] = False

# Remove the test data from the train/val data
train_val_data = pd.DataFrame(metadata[~metadata['md5hash'].isin(test_data['md5hash'])])

synthetic_metadata = generate_synthetic_metadata(train_val_data, generation_type='inpaint', n_synthetic_per_real=10, folder = generation_folder)

# Concatenate the synthetic data with the train/val data
train_val_data = pd.concat([train_val_data, synthetic_metadata]).reset_index(drop=True)

# Split the train/val data into train and val, with 40 images from each label in the val set
real_train_val_data = train_val_data[train_val_data['synthetic'] == False]
val_data = pd.DataFrame(real_train_val_data.groupby(['label']).apply(lambda x: x.sample(n=40, random_state=random_state, replace=False)).reset_index(drop=True))
train_data = pd.DataFrame(train_val_data[~train_val_data['md5hash'].isin(val_data['md5hash'])])

# Add an 'is_valid' column to the train and val data
train_data['is_valid'] = False
val_data['is_valid'] = True
metadata.groupby('label').size()
# show the number of real and synthetic images in the train data, val data, and test data
print("Number of real images in train data: ", len(train_data[train_data['synthetic'] == False]))
print("Number of synthetic images in train data: ", len(train_data[train_data['synthetic'] == True]))
print("Number of real images in val data: ", len(val_data[val_data['synthetic'] == False]))
print("Number of synthetic images in val data: ", len(val_data[val_data['synthetic'] == True]))
print("Number of real images in test data: ", len(test_data[test_data['synthetic'] == False]))
print("Number of synthetic images in test data: ", len(test_data[test_data['synthetic'] == True]))

# %%
# Train a model with 32 real training images per disease condition, plus an additional 10 synthetic images

# %%
# plot some data to compare the performance of these two trials

# %%
# The entire experiment can be run using this script, although this will take a while to run
# !python skin_classification_with_augmentation.py \    
    --dataset hugginface_repo \ 
    --n_real_per_label_list "[1, 8, 16, 32, 64, 128, 228]" \
    --max_batch_size 32 \
    --arg2 value2

# %%
# Now we can plot the data from the complete experiment
# We can provide the user code to reproduce this, but save the trial data so that user can still plot our results if they are unable to run the model
